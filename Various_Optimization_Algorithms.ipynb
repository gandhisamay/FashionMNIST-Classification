# %% [markdown]
# <a href="https://colab.research.google.com/github/gandhisamay/FashionMNIST-Classification/blob/main/Various_Optimization_Algorithms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import pandas as pd
# %matplotlib inline 
import matplotlib.pyplot as plt
import time

# %%
from google.colab import drive 
drive.mount('drive')
# Out:
# Mounted at drive

# %%
# !unzip '/content/drive/MyDrive/Datasets /archive (23).zip'
# Out:
# Archive:  /content/drive/MyDrive/Datasets /archive (23).zip
#   inflating: Admission_Predict.csv
#   inflating: Admission_Predict_Ver1.1.csv

# %%
df = pd.read_csv('/content/Admission_Predict.csv')

# %%
# %cd '/content/drive/MyDrive/Advanced Optimization Techniques '
# Out:
# /content/drive/MyDrive/Advanced Optimization Techniques

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/drive/My Drive/Advanced Optimization Techniques /.git/

# %%
# !git add .

# %%
# !git config --global user.email "gandhisamay200@gmail.com"
# !git config --global user.name "gandhisamay"

# %%
# !git commit -m "Optimizer and Neural Network complete" -m "Made the complete neural network and optimizer still some bugs need to fixed "
# Out:
# On branch master
# Changes not staged for commit:
# 	modified:   Various Optimization Algorithms.ipynb
#
# no changes added to commit

# %%
# !git remote add origin https://github.com/gandhisamay/Advanced-Optimizers-.git
# Out:
# fatal: remote origin already exists.

# %%
# !git push -u origin master
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
username =  'gandhisamay'
git_token = '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'
repository = 'Advanced Optimizers'

# %%
https://github.com/<username>/<repository>
# Out:
#   File "<ipython-input-26-b9a1d25785ca>", line 1
#     https://github.com/<username>/<repository>
#            ^
# SyntaxError: invalid syntax

# %%
# !git remote add origin https://git_token@github.com/gandhisamay/Advanced-Optimizers-.git
# !git remote -v
# Out:
# fatal: remote origin already exists.
# origin	https://github.com/gandhisamay/Advanced-Optimizers-.git (fetch)
# origin	https://github.com/gandhisamay/Advanced-Optimizers-.git (push)

# %%
# !git push origin master
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
features = ['GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
       'LOR ', 'CGPA', 'Chance of Admit ']

x = np.array(df[features])
y = np.array(df['Research'])

# %%
n_val =int( 0.1 * df.shape[0])
print(n_val)

train_indices = shuffled_indices[n_val:]
test_indices = shuffled_indices[:n_val]

x_train = x[train_indices]
x_test  = x[test_indices]

y_train = y[train_indices]
y_test  = y[test_indices]
# Out:
# 40

# %%
class NN:

  def __init__(self,input_size,h1_size,output_size,batch_size):
    #-----Inputs are assigned to the model----#
    self.input_size = input_size
    self.h1_size = h1_size 
    self.output_size = output_size 
    self.batch_size = batch_size
    
    #----Initiailze the weights----#
    self.W1 = np.random.uniform(low = -1,high = 1, size = (self.h1_size,self.input_size))
    self.b1 = np.zeros([self.h1_size,1])
    self.W2 = np.random.uniform(low = -1,high = 1, size = (self.output_size,self.h1_size))
    self.b2 = np.zeros([self.output_size,1])

    parameters = {'W2' : self.W2 , 'b2' : self.b2 , 'W1' : self.W1, 'b1' : self.b1}
    self.parameters = parameters
    
  def forward(self,x):
    self.Z1 = np.dot(self.W1,x) + self.b1
    self.A1 = self.Tanh(self.Z1)

    self.Z2 = np.dot(self.W2,self.A1) + self.b2
    self.A2 = self.Sigmoid(self.Z2)
    return self.A2

  def Loss_fn(self,output,y):
    loss = -np.sum((np.dot(y,np.log(self.A2).T) + np.dot(1-y,np.log(1-self.A2).T))/x.shape[1])
    return loss

  def backward(self,x,y):
    self.dA2 = (self.A2-y)/np.multiply(self.A2,1-self.A2)
    self.dZ2 = self.dA2*self.Sigmoid(self.Z2,derivative = True)
    self.dW2 = np.dot(self.dZ2,self.A1.T)/x.shape[1]
    self.db2 = np.sum(self.dZ2, axis = 1 , keepdims = True)/x.shape[1]
                                                                                                                                                                                                                                
    self.dA1 = np.dot(self.W2.T,self.dZ2)
    self.dZ1 = self.dA1*self.Tanh(self.Z1, derivative = True)
    self.dW1 = np.dot(self.dZ1,x.T)/x.shape[1]
    self.db1 = np.sum(self.dZ1 , axis = 1 , keepdims = True)/x.shape[1]
    
    grads = {'W2' : self.dW2 , 'b2' : self.db2, 'W1' : self.dW1 , 'b1' : self.db1}
    return grads

  def preprocess(self,x,y):
    #----Reshape----#
    if x.shape[1] == self.input_size:
      x = x.reshape(self.input_size,-1)  
      y = y.reshape(1,-1)    
    #----Normalize----#
    x = (x - x.mean(axis = 0))/x.std(axis = 0)

    #----Num of batches----#
    num_batches = x.shape[1] // self.batch_size
    return x,y,num_batches

  #-----Define various activation functions-----#
  def Sigmoid(self,x,derivative = False):
    if derivative == False:
      x = 1/(1 + np.exp(-x))
      return x
    else:
      y = 1/(1 + np.exp(-x))
      return y*(1-y)

  def Tanh(self,x,derivative = False):
    if derivative == False:
      x = np.tanh(x)
      return x
    else:
      y = np.tanh(x)
      return 1-y**2

# %%
class Optimizers:
  def SGD(self,parameters,grads,lr):
    parameters['W2'] -= lr*grads['W2']
    parameters['b2'] -= lr*grads['b2']
    parameters['W1'] -= lr*grads['W1']
    parameters['b1'] -= lr*grads['b1']
    return parameters

  def RMSProp(self,):
    pass 
  def Momentum(self,parameters,grads,lr,beta):
    VdW2 = np.full_like(parameters['W2'],0)
    Vdb2 = np.full_like(parameters['b2'],0)
    VdW1 = np.full_like(parameters['W1'],0)
    Vdb1 = np.full_like(parameters['b1'],0)

    VdW2 = beta*VdW2 + (1-beta)*grads['W2']
    Vdb2 = beta*Vdb2 + (1-beta)*grads['b2']
    VdW1 = beta*VdW1 + (1-beta)*grads['W1']
    Vdb1 = beta*Vdb1 + (1-beta)*grads['b1']

    parameters['W2'] -= lr*VdW2
    parameters['b2'] -= lr*Vdb2
    parameters['W1'] -= lr*VdW1
    parameters['b1'] -= lr*Vdb1
    
    return parameters

  def Adam(self):
    pass

# %%
model = NN(input_size = 7,h1_size = 64,output_size = 1,batch_size = 128)

# %%
opt = Optimizers()

# %%
loss_per_epoch = []
num_epochs = 2000
parameters = model.parameters
x_processed, y_processed, num_batches = model.preprocess(x_train,y_train) 

for epochs in range(1,num_epochs+1):
  tic = time.time()

  outputs = model.forward(x_processed)
  loss = model.Loss_fn(x_processed,y_processed)
  grads = model.backward(x_processed,y_processed)

  parameters = opt.SGD(parameters = parameters, grads = grads , lr = 1e-1)
  loss_per_epoch.append(loss)    

  toc = time.time()
  print("[{}/{}] Loss : {} Time taken : {} us".format(epochs,num_epochs,loss,float(toc - tic)*1000))
# Out:
# [1/2000] Loss : 34.438503154564785 Time taken : 11.362314224243164 us
# [2/2000] Loss : 34.438489932258896 Time taken : 2.6955604553222656 us
# [3/2000] Loss : 34.438476711134264 Time taken : 2.7036666870117188 us
# [4/2000] Loss : 34.43846349118994 Time taken : 2.6640892028808594 us
# [5/2000] Loss : 34.43845027242495 Time taken : 2.6464462280273438 us
# [6/2000] Loss : 34.43843705483837 Time taken : 2.6025772094726562 us
# [7/2000] Loss : 34.43842383842921 Time taken : 2.5980472564697266 us
# [8/2000] Loss : 34.43841062319653 Time taken : 2.596139907836914 us
# [9/2000] Loss : 34.4383974091394 Time taken : 2.6082992553710938 us
# [10/2000] Loss : 34.43838419625682 Time taken : 2.687215805053711 us
# [11/2000] Loss : 34.43837098454788 Time taken : 2.6569366455078125 us
# [12/2000] Loss : 34.43835777401161 Time taken : 2.513885498046875 us
# [13/2000] Loss : 34.43834456464706 Time taken : 2.6543140411376953 us
# [14/2000] Loss : 34.438331356453276 Time taken : 2.5963783264160156 us
# ...

# %%
outputs = np.where(outputs >= 0.5 , 1 , outputs)
outputs = np.where(outputs < 0.5 , 0 , outputs)

# %%
correct = (outputs == y_train.reshape(1,-1)).sum()
print(correct)
# Out:
# 212
